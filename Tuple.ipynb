# %% [markdown]
# <a href="https://colab.research.google.com/github/gupta-aman-kumar/Python-Basics/blob/main/Tuple.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1.Create a tuple of 5 numbers and print last element.
t = (1,2,3,4,5)
print(t[-1])
# Out:
# 5

# %%
# 2.Return the third, fourth, and fifth item:
thistuple = ("apple", "banana", "cherry", "orange", "kiwi", "melon", "mango")
print(thistuple[2:5])
# Out:
# ('cherry', 'orange', 'kiwi')

# %%
# 3.returns the items from "cherry" and to the end:
thistuple = ("apple", "banana", "cherry", "orange", "kiwi", "melon", "mango")
print(thistuple[2:])
# Out:
# ('cherry', 'orange', 'kiwi', 'melon', 'mango')

# %%
# 4.Find the length of a tuple.
t = (1,2,3,4,5)
print(len(t))
# Out:
# 5

# %%
# 5.Check if element 10 exists in (5, 10, 15, 20).
elements = (5,10,15,20)
if 10 in elements:
    print("element found")
else:
    print("element not found")
# Out:
# element found

# %%
# 6.Convert tuple (1,2,3,4) into a list
t= (1,2,3,4)
lst = list(t)
print(lst)
# Out:
# [1, 2, 3, 4]

# %%
# 7.Count how many times 2 appears
t = (1,2,3,2,4,5,2)
mx = t.count(2)
print(mx)
# Out:
# 3

# %%
# 8.Join two tuples (1,2) and (3,4)
t1 = (1,2)
t2 = (3,4)
result = t1 + t2
print(result)
# Out:
# (1, 2, 3, 4)
